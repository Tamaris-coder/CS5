# %% [markdown]
# <a href="https://colab.research.google.com/github/Tamaris-coder/CS5/blob/main/AioLearn2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib import pyplot as plt
import cv2

# %%
image = cv2. imread("tt.jpg")
image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(image)

# %%
model = cv2.CascadeClassifier("model.xml")
